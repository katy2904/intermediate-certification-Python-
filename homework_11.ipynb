# %% [raw]
# ##f(x) = 5x^2 + 10x - 30

# %%
# 1. Определить корни

from math import sqrt

a = 5
b = 10
c = -30

discriminant = b**2 - 4 * a * c

if discriminant > 0:
    x1 = (-b - sqrt(discriminant)) / (2 * a)
    x2 = (-b + sqrt(discriminant)) / (2 * a)
    print(f'x1 = {x1:.2f}; x2 = {x2:.2f}')
elif discriminant == 0:
    x1 = -b / (2 * a)
    print(f'x1 = {x1:.2f}')
else:
    print('Нет корней')
# Out:
# x1 = -3.65; x2 = 1.65

# %% [raw]
# # 2. Найти интервалы, на которых функция возрастает
#
# Мы знаем, что графиком квадратичной функции является парабола. При a > 0 ветви параболы направленны вверх. Соответственно, интервал, на котором функция будет возрастать - это интервал от ее вершины до бесконечности
#
# Более точно определим отрезки в п.5 после нахождения вершины параболы

# %% [raw]
# # 3. Найти интервалы, на которых функция убывает
#
# Мы знаем, что графиком квадратичной функции является парабола. При a > 0 ветви параболы направленны вверх. Соответственно, интервал, на котором функция будет убывать - это интервал от минус бесконечности до вершины параболы
#
# Более точно определим отрезки в п.5 после нахождения вершины параболы

# %%
# 4. Построить график

from sympy.plotting import plot

plot(y)
print(y)
# Out:
# 5*x**2 + 10*x - 30

# %%
# 5. Вычислить вершину

a = solve(y.diff(x))[0]
b = y.subs(x, a)

print(f'Вершина функции {y} находится в точке [{a}; {b}]')

print(f'На участке (-∞,{a}) функция убывает')
print(f'На участке ({a}, ∞) функция возрастает')
# Out:
# Вершина функции 5*x**2 + 10*x - 30 находится в точке [-1; -35]
# На участке (-∞,-1) функция убывает
# На участке (-1, ∞) функция возрастает

# %% [raw]
# # 6. Определить промежутки, на котором f > 0
# # 7. Определить промежутки, на котором f < 0
#
# Как уже говорилось, грфиком квадратичной функции является парабола. В нашем случае, т.к. а > 0 ветви параболы направленны вверх. Кроме того, у нашей функции дискриминант больше 0 и имеются два корня х1 и х2.
# Корни х1 и х2 - это точки перессечения параболы с осью Х, т.е.точки, где значения функции равны 0. Соответственно, на оси Х мы имеем три отрезка на которых значения функции принимают следующие значения:
#
# (-∞,-3.65) - f>0 - функция принимает положительные значения
# (-3,65, 1.65) - f<0 - функция принимает отрицательные значения
# (1.65, ∞) - f>0 - функция принимает положительные значения
